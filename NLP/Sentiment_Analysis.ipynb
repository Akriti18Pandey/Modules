# %%
pip install textblob  #for sentiment analysis,text classification, POS
# Out:
# Collecting textblob
#   Downloading textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: nltk>=3.9 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from textblob) (3.9.4)
# Requirement already satisfied: click in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.9->textblob) (8.3.1)
# Requirement already satisfied: joblib in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.9->textblob) (2026.4.4)
# Requirement already satisfied: tqdm in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.9->textblob) (4.67.3)
# Requirement already satisfied: colorama in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.20.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    --------------------------------------- 625.0/625.0 kB 11.7 MB/s eta 0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.20.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from textblob import TextBlob
import spacy

# %%
# load spacy model
nlp=spacy.load("en_core_web_sm")

# %%
# take input from user
text=input("Enter the text:")

#Sentiment analysis
blob=TextBlob(text)

polarity =blob.sentiment.polarity
print("Polarity score :",polarity)

if polarity >0:
    print("Sentiment is Positive")
elif polarity < 0:
    print("Sentiment is Negative")
else:
    print("Sentiment is Neutral")

#NER
xyz=nlp(text)

print("Entity Analysis:")

for ent in xyz.ents:
    print(ent.text," ",ent.label_)

# POS tagging

print("Part of speech Tagging (POS)")

for token in xyz:
    print(f"{token.text} - {token.pos_}")
# Out:
# Enter the text: India, officially the Republic of India, is a country in South Asia. It is the seventh-largest country by area; the most populous country since 2023; and, since its independence in 1947, the world's most populous democracy
# Polarity score : 0.5
# Sentiment is Positive
# Entity Analysis:
# India   GPE
# the Republic of India   GPE
# South Asia   LOC
# seventh   ORDINAL
# 2023   DATE
# 1947   DATE
# Part of speech Tagging (POS)
# India - PROPN
# , - PUNCT
# officially - ADV
# the - DET
# Republic - PROPN
# of - ADP
# India - PROPN
# , - PUNCT
# is - AUX
# a - DET
# country - NOUN
# in - ADP
# South - PROPN
# Asia - PROPN
# . - PUNCT
# It - PRON
# is - AUX
# the - DET
# seventh - ADV
# - - PUNCT
# largest - ADJ
# country - NOUN
# by - ADP
# area - NOUN
# ; - PUNCT
# the - DET
# most - ADV
# populous - ADJ
# country - NOUN
# since - SCONJ
# 2023 - NUM
# ; - PUNCT
# and - CCONJ
# , - PUNCT
# since - SCONJ
# its - PRON
# independence - NOUN
# in - ADP
# 1947 - NUM
# , - PUNCT
# the - DET
# world - NOUN
# 's - PART
# most - ADV
# populous - ADJ
# democracy - NOUN
