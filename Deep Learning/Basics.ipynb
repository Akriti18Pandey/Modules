# %%
from sklearn.datasets import load_iris

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
#load dataset
data=load_iris()
x=data.data
y=data.target

# %%
#one_hot encoding
y=to_categorical(y,3)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
# Build neural network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential([
    Dense(10,activation='relu', input_shape=(4,)),
    Dense(8,activation='relu'),
    Dense(3,activation='softmax')
])

# %%
#compile model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

# %%
#train model
pred=model.fit(         #80% training the data
    x_train,y_train,
    epochs=60,
    batch_size=8,
    validation_data=(x_test,y_test))   # 20% for testing the train model
# Out:
# Epoch 1/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9833 - loss: 0.0760 - val_accuracy: 0.9667 - val_loss: 0.1156
# Epoch 2/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9833 - loss: 0.0771 - val_accuracy: 0.9333 - val_loss: 0.1138
# Epoch 3/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9917 - loss: 0.0766 - val_accuracy: 0.9667 - val_loss: 0.1254
# Epoch 4/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9833 - loss: 0.0792 - val_accuracy: 0.9667 - val_loss: 0.1177
# Epoch 5/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9833 - loss: 0.0781 - val_accuracy: 0.9667 - val_loss: 0.1081
# Epoch 6/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9833 - loss: 0.0739 - val_accuracy: 0.9667 - val_loss: 0.1221
# Epoch 7/60
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9917 - loss: 0.0738 - val_accuracy: 0.9667 - val_loss: 0.1166
# Epoch 8/60
# ...

# %%
from sklearn.datasets import load_wine

# %%
data=load_wine()
x=data.data
y=to_categorical(data.target,3)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=Sequential([
    Dense(16,activation='relu', input_shape=(x.shape[1],)),
    Dense(10,activation='relu'),
    Dense(8,activation='relu'),
    Dense(3,activation='softmax')
])

# %%
#compile model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])

# %%
#train model
pred=model.fit(         #80% training the data
    x_train,y_train,
    epochs=60,
    batch_size=8,
    validation_data=(x_test,y_test)) #hyperparameters
# Out:
# Epoch 1/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2254 - loss: 12.6122 - val_accuracy: 0.0278 - val_loss: 6.1172
# Epoch 2/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0986 - loss: 5.5850 - val_accuracy: 0.1111 - val_loss: 3.4761
# Epoch 3/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2465 - loss: 2.0181 - val_accuracy: 0.2500 - val_loss: 1.2241
# Epoch 4/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5493 - loss: 1.0091 - val_accuracy: 0.5556 - val_loss: 0.8901
# Epoch 5/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5563 - loss: 0.9043 - val_accuracy: 0.6111 - val_loss: 0.8642
# Epoch 6/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6408 - loss: 0.8609 - val_accuracy: 0.7500 - val_loss: 0.7734
# Epoch 7/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6549 - loss: 0.8004 - val_accuracy: 0.6944 - val_loss: 0.7478
# Epoch 8/60
# ...

# %%
model.evaluate(x_test,y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8056 - loss: 0.4114
# [0.4114435911178589, 0.8055555820465088]
