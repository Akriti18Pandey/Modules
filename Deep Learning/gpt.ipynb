# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (5.5.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from transformers) (1.9.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2026.4.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: colorama in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from typer->transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\akrit\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import pipeline  ## this function helps in loading model text generation, sentiment analysis, translationgen

# %%
generator=pipeline("text-generation",model="gpt2")
prompt=input("Enter your prompt:")
result=generator(prompt, max_length=50)
print(result[0]['generated_text'])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Enter your prompt: artificial intelligence
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# artificial intelligence  (AI) is a scientific term for intelligence that has been around for over 40 years. It has been used to describe the ability of humans to predict future events based on information from the various sources (such as real-time information from the news media, information from social media, and the internet).
# The term AI first appeared in the 1960s and was coined by the British psychologist, Sir Malcolm Gladwell. He called it the "Machine Intelligence" because of its ability to predict events and provide information. It was the first technology to directly interact with the human brain, allowing it to do so without conscious thought. The term is still used today as a synonym for intelligence.
# In the early 1970s, researchers began to use the term to describe intelligence using AI to predict future events. The term was coined by John D. Rockefeller to describe the way in which computers are able to predict future events that they do not fully understand or anticipate.
# The term can mean a different thing to humans than it does to AI. The term is a synonym for human intelligence.
# It is true that AI can think, but it can also make decisions. When it is thinking, it has to make decisions. The words "intelligent" and "intelligent"
